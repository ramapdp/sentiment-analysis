# %%
twitter_auth_token = "AUTH_TOKEN_HERE"

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# v20.11.1

# %%
filename = 'MBG-data1.csv'
search_keyword = 'MBG since:2025-01-06 until:2025-10-09 lang:id'
limit = 5000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: MBG since:2025-01-06 until:2025-10-09 lang:id
#
#  (2) (3) (4)
#
# Your tweets saved to: c:\personal-project\sentiment-analysis-mbg\tweets-data\MBG-data1.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: c:\personal-project\sentiment-analysis-mbg\tweets-data\MBG-data1.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: c:\personal-project\sentiment-analysis-mbg\tweets-data\MBG-data1.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# ...

# %%
import pandas as pd

filename = './tweets-data/MBG-data1.csv'

df = pd.read_csv(filename)
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1976072778429366410  Wed Oct 08 23:50:38 +0000 2025               0
# 1  1976072619607892013  Wed Oct 08 23:50:00 +0000 2025               0
# 2  1975827587986510011  Wed Oct 08 23:49:40 +0000 2025               0
# 3  1975814460486131874  Wed Oct 08 23:49:01 +0000 2025               0
# 4  1975736601293807719  Wed Oct 08 23:48:28 +0000 2025               0
#
#                                            full_text               id_str  \
# 0  Program Makan Bergizi Gratis (MBG) bukan cuma ...  1976072778429366410
# 1  Langkah cepat dari Istana Presiden Prabowo Sub...  1976072619607892013
# 2  @Jateng_Twit @kabarklaten Tiada hari tanpa ker...  1976072536220893375
# 3  @wordsmithtobe @somexthread Pengen makan sehat...  1976072371862958458
# 4   @KangManto123 Goblog. Ndhuwe dapur MBG piro pak?  1976072230544212427
#
#                                          image_url in_reply_to_screen_name  \
# ...

# %%
num_tweets = df.shape[0]
print(f"Number of tweets collected: {num_tweets}")
# Out:
# Number of tweets collected: 5011

# %%
# Create a copy of the dataframe and select specific columns
df_copy = df[['created_at', 'full_text', 'favorite_count', 'quote_count', 'reply_count', 'retweet_count', 'tweet_url']].copy()
df_copy.head(15)
# Out:
#                         created_at  \
# 0   Wed Oct 08 23:50:38 +0000 2025
# 1   Wed Oct 08 23:50:00 +0000 2025
# 2   Wed Oct 08 23:49:40 +0000 2025
# 3   Wed Oct 08 23:49:01 +0000 2025
# 4   Wed Oct 08 23:48:28 +0000 2025
# 5   Wed Oct 08 23:48:18 +0000 2025
# 6   Wed Oct 08 23:48:03 +0000 2025
# 7   Wed Oct 08 23:47:47 +0000 2025
# 8   Wed Oct 08 23:47:17 +0000 2025
# 9   Wed Oct 08 23:46:50 +0000 2025
# 10  Wed Oct 08 23:46:42 +0000 2025
# 11  Wed Oct 08 23:45:58 +0000 2025
# 12  Wed Oct 08 23:45:54 +0000 2025
# 13  Wed Oct 08 23:45:54 +0000 2025
# 14  Wed Oct 08 23:45:50 +0000 2025
#
#                                             full_text  favorite_count  \
# 0   Program Makan Bergizi Gratis (MBG) bukan cuma ...               0
# 1   Langkah cepat dari Istana Presiden Prabowo Sub...               0
# 2   @Jateng_Twit @kabarklaten Tiada hari tanpa ker...               0
# 3   @wordsmithtobe @somexthread Pengen makan sehat...               0
# ...

# %%
df_copy.to_csv('MBG-data-cleaned.csv', index=False)
